# %%
# !xcode-select --install
# Out:
# xcode-select: error: command line tools are already installed, use "Software Update" in System Settings to install updates

# %%
# !conda install -c apple tensorflow-deps
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - apple
#  - conda-forge
#  - anaconda
# Platform: osx-arm64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.3.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/dom/miniconda3/envs/images
#
#   added / updated specs:
#     - tensorflow-deps
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     c-ares-1.32.0              |       h99b78c6_0         154 KB  conda-forge
#     grpcio-1.46.3              |  py310ha26ec5d_0         2.2 MB  conda-forge
#     h5py-3.6.0                 |nompi_py310hb8bbf05_100         1.3 MB  conda-forge
#     krb5-1.20.1                |       h69eda48_0         1.0 MB  conda-forge
# ...

# %%
#!pip install tensorflow-macos==2.16.1

# %%
# !pip install tensorflow==2.16.1

# %%
# !pip install tensorflow-metal==1.1.0

# %%
# !pip install numpy==1.26.4

# %% [markdown]
# Tensorflow and Keras compatibility: https://mckayward.github.io/floyd-docs/guides/environments/

# %%
import sys

import tensorflow
import keras
import pandas as pd
import sklearn as sk
import scipy as sp
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
print(f"SciPy {sp.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-13.0-arm64-arm-64bit
# Tensor Flow Version: 2.16.1
# Keras Version: 3.4.1
#
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:51:49) [Clang 16.0.6 ]
# Pandas 2.2.2
# Scikit-Learn 1.5.1
# SciPy 1.14.0
# GPU is NOT AVAILABLE

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Problems with the tnesorflow and keras installation:
# - tensorflow==2.16.1 & tensorflow-metal==1.1.0 & NO tensorflow-macos -> GPU available
#
# [libprotobuf FATAL google/protobuf/message_lite.cc:353] CHECK failed: target + size == res:
# libc++abi: terminating with uncaught exception of type google::protobuf::FatalException: CHECK failed: target + size == res:
#
# - tensorflow==2.16.1 -> GPU unavailable
#
# - tensorflow-macos==2.16.1 & tensorflow-metal==1.1.0 -> GPU available
#
# [libprotobuf FATAL google/protobuf/message_lite.cc:353] CHECK failed: target + size == res:
# libc++abi: terminating with uncaught exception of type google::protobuf::FatalException: CHECK failed: target + size == res:
#
#
# - tensorflow-macos==2.16.1 & tensorflow-metal==1.1.0 & tf_keras (legacy with TF_USE_LEGACY_KERAS = 1) -> GPU available
#
# [libprotobuf FATAL google/protobuf/message_lite.cc:353] CHECK failed: target + size == res:
# libc++abi: terminating with uncaught exception of type google::protobuf::FatalException: CHECK failed: target + size == res:
#
# - tensorflow==2.14 & tensorflow-metal==1.1.0 -> keras not importable
#
# ImportError: cannot import name 'disable_resource_variables' from 'tensorflow.python.ops.variable_scope' (/Users/dom/miniconda3/envs/image-iot/lib/python3.10/site-packages/tensorflow/python/ops/variable_scope.py)
#
# - tensorflow==2.16.1 & no other packages (keras is included) -> GPU is available

# %% [markdown]
# ## Conclusion
# Tensorflow + tensorflow-metal dependencies work together for model training but not for loading models from checkpoints.
# For this pupose only tensorflo without GPU through metal is available
